# %%
import numpy as np
from matplotlib import image
from sklearn.cluster import KMeans
from turtle import shape
from util.constants import Topic, THUMBNAIL_HEIGHT, THUMBNAIL_WIDTH, THUMBNAIL_PATH
from tqdm import tqdm
from PIL import Image
import numpy as np
import json
import os
import matplotlib.pyplot as plt

def rgb_to_hex(rgb):
    return '#%02x%02x%02x' % rgb

def make_image_grid_1_row(imgs):
    w, h = imgs[0].size
    cols = len(imgs)

    grid = Image.new('RGB', size=(w * cols, h))
    
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i % cols*w, i//cols*h))
    return np.array(grid)


def make_image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols

    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return np.array(grid)


def find_dom_colours_with_percentages(img, clusters):
    _, _, C = img.shape
        
    # resize so kmeans is faster
    img = np.resize(img,(100, 200, C))

    # remove dark colours from image
    img = img[img[:,:,0] + img[:,:,1] + img[:,:,2] > 50]
    
    flat_img = np.reshape(img,(-1,3))

    kmeans = KMeans(n_clusters=clusters, random_state=0)
    kmeans.fit(flat_img)

    dominant_colors = np.array(kmeans.cluster_centers_, dtype='uint8')
    dominant_colors = tuple(map(tuple, dominant_colors))
    dominant_colors = [rgb_to_hex(dom_color) for dom_color in dominant_colors]

    percentages = (np.unique(kmeans.labels_, return_counts=True)[1]) / flat_img.shape[0]
    percentages = [round(perc, 3) for perc in percentages]

    c_and_p_dict = {"colours" : dominant_colors, "perc" : percentages}

    _, ax1 = plt.subplots()
    _, _, m = ax1.pie(percentages, autopct='%1.1f%%', colors=dominant_colors, shadow=True, startangle=90)
    [m[i].set_color('white') for i in range(len(m))]
    ax1.axis('equal') 

    plt.show()

    # dc_and_p = zip(dominant_colors, percentages)
    # dc_and_p = sorted(dc_and_p, reverse = True)

    # dc_and_p_dict = {}
    # for k, v in dc_and_p:
    #     dc_and_p_dict[k] = v


    return c_and_p_dict


def extract_category_dom_colours(category: Topic, clusters):
    """
    Function to extract dominant colours per creator and category for the given category.

    args:
        - category: the given category
    """

    with open(os.path.join("..", "data", "info_videos", f"videos-info_{category}.json"), "r") as f:
        print("Loading creator's videos")
        videos_info = json.load(f)
    print("Finished loading creator's videos\n")

    print("Calculating dominant colours for all creators in category: " + category + "\n")
    all_category_thumbnails = []
    for creator in tqdm(list(videos_info.keys())):
        print(creator)
        all_creator_thumbnails = []
        
        try:
            creator_thumbnails = []
            for vid_dict in videos_info[creator]:
                img = Image.open(os.path.join(THUMBNAIL_PATH, vid_dict['id'] + "_high.jpg"))
                w, h = img.size
                if h == THUMBNAIL_HEIGHT and w == THUMBNAIL_WIDTH:
                    # we exclude shorts by skipping the videos that were not cropped
                    continue
                creator_thumbnails.append(img)
            if len(creator_thumbnails) < 5:
                continue

            all_creator_thumbnails.extend(creator_thumbnails)

            all_category_thumbnails.extend(all_creator_thumbnails)

        except FileNotFoundError:
            continue

        img_grid = make_image_grid_1_row(all_creator_thumbnails)

        plt.imshow(img_grid)
        plt.show()

        dom_colours = find_dom_colours_with_percentages(img_grid, clusters)

        with open(os.path.join(CREATORS_PATH, creator + ".json"), 'w') as f:
            json.dump(dom_colours, f)
        
    print("Calculating dominant colours for category: " + category + "\n")

    img_grid = make_image_grid_1_row(all_category_thumbnails)
    dom_colours = find_dom_colours_with_percentages(img_grid, clusters)

    plt.imshow(img_grid)
    plt.show()

    with open(os.path.join(CATEGORY_PATH, creator + ".json"), 'w') as f:
        json.dump(dom_colours, f)

    print("Finished calculating dominant colours per creator and for category\n")


if __name__ == '__main__':

    CATEGORY_PATH = "../data/thumbnail-dom-colours/categories"
    CREATORS_PATH = "../data/thumbnail-dom-colours/creators"

    if not os.path.exists(CATEGORY_PATH):
        os.makedirs(CATEGORY_PATH)

    if not os.path.exists(CREATORS_PATH):
        os.makedirs(CREATORS_PATH)

    # choose how many colours to extract
    clusters = 5

    for category in Topic:
        extract_category_dom_colours(category.value, clusters)
        # only do gaming for now
        break
# Out:
# Loading creator's videos
# Finished loading creator's videos
#
# Calculating dominant colours for all creators in category: gaming
#
# jaze-cinema
# casaldenerd
# poke
# epicpb-thgame
# magmamusen
# rachitroo
# g0ularte
# skip-the-tutorial
# mm7games
# beaconcream
# vladus
# le-bled-art
# screwattack
# robzi
# 09sharkboy
# agustin51
# faze-jev
# estubegaming
# xbox
# sirkazzio
# eugenesagaz
# basicallyidowrk
# d4rkframe
# leah-ashe
# geleia
# tmartn2
# keifermc-todo-sobre-minecraft
# swaggersouls
# thealvaro845-clash-royale-clash-of-clans
# prestige-clips
# whitezunder
# forge-labs
# mini-ladd
# red-arcade
# febatista
# ideias-incriveis-girls
# quantum-games
# oops-banana
# smii7y
# alphasniper97
# behzinga
# killercreeper55-minecraft
# the-official-pokemon-channel
# sup3r-konar
# logdotzip
# tapgameplay
# carol-azeredo
# pyrocynical
# 315d673b-8ec6-4766-a18e-c517f64642cd
# wisp
# hugoposay
# 230dd267-7327-41f8-a270-4b627fdde9e5
# mrdsaster
# eystreem
# zerkaa
# formula-e56756ec-2d11-4409-9391-96883599a09b
# mongraal
# tmfaisal
# day-helder
# xnestorio
# friz
# garena-free-fire-vietnam
# kubz-scouts
# mellamanfredy
# myth
# martin-shacoscu
# tim-thetatman
# cherryrar
# cinnamontoastken
# serum
# tex-hs
# kindly-keyin
# thewarpath
# pratama-eriz
# alice-slime
# rezigiusz
# st3pny
# over-show
# raily
# folagor03
# socksfor1
# cashnastygaming
# spreen
# atro-plus
# let-s-game-it-out
# ea-sports-fifa
# ghostninja
# beckbrojack
# mobile-moba-vi-t
# bobicraft
# luke-thenotable
# sketch-roblox-more
# stuu-games
# bugha
# briannaplayz-82bc129b-dcc5-43be-93ca-ee31235e4bdc
# iballisticsquid
# home-of-games
# mindofrez
# flight
# kreekcraft
# gevids
# ronaldomg
# hollowpoiint
# cizzorz
# antonio-palmucci
# random-encounters
# scary-teacher-3d-hile
# rb-playing
# tofuu
# fundy
# m3rkmus1c
# rick-marin
# pubg-mobile-esports
# jt-machinima
# littlelizardgaming-minecraft-mods
# sesegel
# vitoria-mineblox
# lucky-maker
# jesserthelazer
# beamng-nation
# ludwig
# ethangamertv-egtv
# maxinfinite
# funkyblackcat
# uberhaxornova
# daily-fortnite-battle-royale-moments
# bblocks
# got-drums
# craftee
# call-me-kevin
# ilvostrocarodexter
# ohlongjohnson-clash-royale-funny-moments-montage
# dp-gaming
# surreaipower
# kreyk
# the-corvus-clan
# gerand
# youalwayswin
# thesmithplays
# elgin-mobile-legends
# tinenqa
# video-game-news
# luky
# perpetuumworld
# vietnam-esports-tv
# the-spiffing-brit
# redhatter
# clash-royale-en-espanol
# felps
# ph1lza
# bon-gamerz
# spycakes
# igameplay1337
# yammy-xox
# lstoast
# dark-corners
# callmecarson
# joey-graceffa-911a008c-bb98-4655-9d4d-9a4eb51f2293
# deigamer
# kozmik-karinca
# rfm-vs-games
# icrimax
# 2-hajime
# sarinha
# dilleron
# dakotaz
# m-u-ho-t-hinh
# exility
# venturiantale
# oka
# click-ebe08c53-cfac-4ae1-8872-3cdd3a201b5b
# two-players-one-console
# communitygame
# king-crane
# orange-juice-gaming
# fortnite-funny
# camodo-gaming
# welyn
# yandere-dev
# mattshea
# arcadecloud
# chaosxsilencer
# valouzz-eclypsia
# ant
# loltyler1
# dan-bull
# noahsnoah
# vitec-play
# zerkaaplays
# edd00chan
# thedavidvtv
# war-robots-wr
# umidi
# rtgame-3648dc42-1873-4471-a746-ab78a1eef722
# ameer-slow
# lam-tv
# dimucc
# amustycow
# spontana-black
# apex-legends
# gabby16bit
# theskylanderboy-andgirl
# extra-credits
# juicy-03ac713b-1900-4e21-9a93-f9d23d21a3c3
# outsidexbox
# hard-play
# alexa-real
# zailetsplay
# skinspotlights
# adin-live
# captain-tate
# guitarherostyles
# zylbrad
# hornstromp-games
# 81c4a1c3-10ac-49c7-8bb1-b7e95f799134
# best-in-class
# chief-pat-clash-royale-clash-of-clans
# mrdalekjd
# skyrroz
# gamingwithmolt
# mechanic
# john-morin
# sambucha
# pungence
# russoplays
# baris-bra
# swaggxbl
# nightblue3
# modo-kamikaze
# mcpejournalist
# nuckem
# whiteboy7thst
# jellybean
# captainsauce
# bitgamer
# oyun-portal
# xmurry
# consolesejogosbrasil
# truemu-minecraft-universe
# oyun-delisi
# officialnerdcubed
# bay-area-buggs
# aenhgames
# apixelados-minecraft-troll
# draegast
# vito
# gcaothu-channel
# crispy-concords
# newscapepro-fortnite-shorts-films-and-skits
# thefriendlymachine
# fuze-iii
# mrshadyman
# jmx
# izuniy
# elanip
# gamer-s-little-playground
# handofblood
# matthdgamer
# arazhul
# masterov-gaming-channel
# also-fitz
# fuziondroid
# pack-a-puncher
# iraphahell
# igp
# playadoptme
# b4fa3a41-3520-4655-ad4f-72be16d21160
# dankscole
# menos-trece
# minecraft-evi
# ethoslab
# athos
# wankil-studio-laink-et-terracid
# hitesh-ks-hindi-gaming
# pandu-gaming
# tv-41cf769e-512c-4271-a845-73d39fa34bc8
# checkpoint
# gizzy-gazza
# nickatnyte
# gereksiz-oda
# rania-gaming
# cbgames
# mr-gg
# kaluch
# hyper-roblox
# sunfesoverload
# stonemountain64
# cashnastyplays
# deadpies
# siphano
# graenolf
# dobbs
# matt-amanda
# shubble
# aid
# 401c8a16-b7e5-49d2-8587-bd17f62ad59b
# petezahhutt
# thatpunchkid
# coletheman-tw
# itsdestv
# mihdens
# bandai-namco-entertainment-america
# kairostime-gaming
# metaljesusrocks
# hetgameportaal
# partiallyroyal
# darkk-mane
# fifalosophy
# locandro
# ohnickel
# andybttf-productions
# baxtrix
# noahjafk
# 720bd353-9026-4f65-8706-48be850874ed
# babydino-nursery-rhymes-and-kids-songs
# zeus-5742b23d-bb97-4029-936f-a62162a6419f
# flemlo-raps
# everynightxriot
# 4kidsgaming
# 602356d2-d765-4b96-b383-b7664bd1e0af
# tv-6f242f97-b10c-4679-bab3-8d31ef23516e
# squirrel
# hatsy
# phoeberry
# brutalmoose
# badgeplug
# bendy-dubs-tv-comic-dub
# kootra
# 62164897-d67d-4daa-8b17-fbfdccbda1d7
# cannibal-crab-minecraft
# magmuz
# mooseblox
# 9ebb4759-9a0e-481a-8954-52bb5b5a3778
# quiff
# cheru
# touchgameplay
# tv-990327e4-fa00-4639-87a1-6b8164c12a97
# pixlriffs
# kevin-kenson
# whosimmortal
# westie
# rossboomsocks
# gta5videos
# pbggameplay
# unknown-player
# laucs
# newscapepro-4-fortnite-minigames-challenges
# heavenly-controller
# cubfan135
# hashtag-harry
# truegreen7
# skill-up
# happydays-8edfdc8f-d63c-4a78-93e7-9dad55f4c190
# ethobot
# cyranek
# game-my
# zeroyalviking
# bunny-funny
# funke
# spacehamster
# tamga-studio
# mgh
# cleanshot
# chuck
# john-wolfe
# daggerwin
# botezlive
# kraken-kid-minecraft
# legends-of-gaming
# tapwater
# caubengungo-official
# funwithguru
# kaggyfilms-alejandro-saab
# honkai-impact-3rd
# littlesiha
# gv-among-us
# tearofgrace
# gamecin
# 52489cab-9c80-4530-b142-fed1706d2938
# elementgames
# mobile-gameplay
# shadic
# harryninetyfour
# buzz-a16c34fb-6b5a-4706-81a4-df6393df2fb0
# acg
# seniac
# hyun
# hikaru-games
# bestinslot
# stampylongnose
# star_
# trump
# yarasky
# mcskillet
# 63de7df2-99d5-4ad3-8e2b-8c7d54b89053
# vargskelethor-vinesauce-joel
# macmacs
# jorraptor
# klasicangamer
# thefrizkyfrog
# rango-games
# embear
# tanjingames
# firstthirtyminutes
# sp00nerism
# oddheader
# seri-pixel-biologist
# gegcoin
# lispyleaf
# enzo-knol
# halo-5db66eb1-f64a-4c5c-b4f5-f543c1efce5a
# microguardian
# indeimaus
# kandyrew
# danny-aarons
# pianta
# tfs-gaming
# mkelite
# spllitz
# favremysabre
# altijdcompilaties
# super-gt
# starsnipe-daily-videos
# mcsportzhawk
# android-faaee731-c63d-4667-acfa-96849aecc42e
# salty-phish
# nanogenix
# halofollower
# themediacows
# opticbigtymer
# vinesauce
# seereax
# thesw1tcher
# callmearj
# forever-nenaa
# mitr0
# jacksucksatgeography
# zaccoxtv
# mandaloregaming
# infernoplus
# perfect-score
# captain-eggcellent
# jacksucksatstuff
# scrapman
# games-3ed7d10e-4b4d-478a-80ae-b639df1d60c4
# xdarzethx-roblox-more
# 445c0ee7-4c69-4c5c-b07b-45dbe50d969b
# entak
# iifnatik
# sanninshow
# the-command-zone
# team-forknife
# lolvoyboy
# kfc-clash
# derium-s-pokemon
# cast-theatre
# protomario
# calloftreyarch
# hybridpanda
# oakelfish
# hornstromp-3d
# dodo
# tech-yes-city
# mustard-plays
# playfifanl
# teveelgevraagd
# jaavelin
# 7ef2f182-9df0-4533-9b87-89f8ca920fd7
# rimmy-downunder-gaming
# twitch-clips-central
# tomographic
# clutch
# ctoretto
# antdude
# sirtagcr-clash-royale
# none-like-joshua
# rockit-gaming
# tbag-epic-gaming
# prod
# silvergames
# luckygraafnl
# gamenews-playstation
# clonny-games
# sea-c11b2f91-1f1e-45a2-ac28-67386d613a10
# total-war
# digital-car-addict
# fluump
# limmy
# squiddyplays
# minionfartgun
# birdo
# jt-e93a10b5-a0f8-4d3b-9c87-38fb39cac14b
# c9-tarik
# jayuzumi
# aliensrock
# the-easter-egg-hunter
# byze
# wowcrendor
# pythonmc
# calbel
# ki11er-six
# lowkotv
# biggs87x
# fugglet
# sharv
# psisyndicate
# fruity
# lanceypooh
# danteaxeproduction
# bancily
# fc-roelie
# burcol
# matt-lowne
# hungrybox
# brartv
# gacha-animations
# sneaky
# wronchi-animation
# mrmattyplays
# luokho-animation
# suzy-lu
# generalmcbadass
# introspecktive
# the-games
# ktxtreme-gaming
# wilburgur
# freddy
# the-8-bit-ninja
# the-axeman
# onecheesymofo
# dash-star
# nixxiom
# hudson-s-playground-gaming
# zerkaaclips
# cone-11
# squire
# phantom-fear
# blue-television-games
# verlisify
# torvestars
# jayex23-gaming-based-entertainment
# oliwhitegames
# fighter-pl
# thomas-game-docs
# guru-mobile-game
# bbpanzu
# dynasty
# pizo
# postboxpat-next-level
# rey-brawl-stars
# ecoliespresso
# bluedrake42
# ezekielgaminghd
# brentalfloss
# roediementair
# rag-tagg
# hamaji-neo
# cosmo-76964174-2cbf-4b33-83ed-278b41742b0b
# jeremy-gaming-curios
# preach-gaming
# igcompany
# g-rated-family-gaming
# thexpgamers
# dagwummy
# kinnikuchu
# cromotag
# xurbansimsx
# youtube-brackets
# thedutchterms
# ericrayweather
# it-s-luke
# jacob-gaming
# vargskelethor-uncut-full-joel-streams
# cullenburger
# sensationlive
# chubbydino
# lionheartx10
# paraduze
# falsesymmetry
# rememberthebeat
# bajheerawow
# larry-bundy-jr
# rgt-85
# caspersight
# thesandyravage
# twinmators
# legendoftotalwar
# yippee-ki-yay-mr-falcon
# entoanthepack
# ndukauba
# purplematter
# thekingnappy
# planetdestiny
# a1mostaddicted-minecraft
# tbot
# cheridet
# vthorben
# jarradhd
# itsmellslikehonor
# esports-talk
# acidic-blitzz
# thegamingrevolution
# itspaikon
# herovoltsy
# clash-on-gan-clash-royale-clash-of-clans
# marcus-house
# solidarity
# johneawesome
# figureight
# bananaflavourhd
# patterrz
# whitelight
# mauler
# drakulis-cinematic-gaming
# tamago2474
# itsjackcole
# framed
# overwatch-central
# twd98
# nintendocaprisun
# canisports
# marriland
# wipper
# sb737-live
# turtlederp
# giant-bomb
# xbraker-mobile-1bcae0f1-572d-441c-aa10-c654333d5b49
# google-play-korea
# quygames-2016
# tass
# ray-dhimitri
# meloo
# switchup
# gouki-games
# anonymousaffection
# austin-felt
# overwatch-moments-sparktv
# zeroxfusionz
# atro-shorts
# lol-moments-gaming-curios
# jittered
# pat-the-nes-punk
# vakogames
# axtraa
# geek-street
# the-shermanator
# sv2-57be3a0b-8eb8-42ba-8c1f-3aafbf3067dd
# tyrodin
# thijs-hearthstone
# denniskuhh
# theredengineer
# enterelysium
# master-gaming
# dutch-nfs-gaming
# method
# vapex-karma
# corruptcarnage
# easynow
# shibui
# mattjestic-multigaming
# igv-ios-and-android-gameplay-trailers
# tcaptainx
# solokiso
# amberry-games
# team-spooky
# gta-wise-guy
# nephop11
# snedger
# oplolreplay
# hopcat
# dota-2-rapier
# 3e2c9c70-c117-4cc7-a0e9-e2dc6bcdad72
# joocie
# notrodan
# eiaz
# kosh
# lekker-spelen
# mayor-mori
# taureor
# alex-klein-2
# gamerrzombie
# ro0oney
# mfpallytime
# sitrush
# arcadetoon
# itsunclesam
# afunkydiabetic
# sooo-mungry
# t-virus-films
# jurassic-world-evolution-2
# elz-the-witch
# ahnaldt101
# dark-anti
# angry-thomas
# laymen-gaming
# netmarble-global
# final-fantasy-xv
# dota-2-meta
# jake-globox-minecraft-xbox
# spark-squared
# fifa-bawz
# worldofjcc
# skye-storme
# xeraingaming
# waytwo
# pdwinnall
# amstudio
# nicob
# bull-bosphorus
# minimme
# maximumandroid-just-good-games
# minecraftdotnet-minecraft-community-channel
# games4real
# loleventvods-lol-esports-vods
# dota-2-divine
# icycaress
# omgitstiesto
# big-baseball
# mickschellens
# poke-ak
# myphex
# let-s-play-games
# rich-leigh
# jordystorm
# daddy
# simply-austin
# sasportsgaming
# jackie-fish
# 64ios
# itemp
# dodo-fortnite
# harm2
# thebitblock
# hoolopee
# kaleidow
# marnickur
# thelonelygoomba
# writing-on-games
# mlp-kids-games
# pvpskillz
# max-mears
# liamftwinter
# gerlaenco
# lord-spinkingham-team-delta
# qucee-gaming
# oasisonoverwatch
# lord-dakr
# le96z
# pipboy-fresh
# crowned
# superrebel
# mariodragon
# midnan
# customname
# games-night
# bazamalam
# jp24gm
# thomas3316
# whoisthisgit
# stephenplays
# boredgamer
# cyberman65
# lazerzz
# star-city-games
# milkandcookiestw
# thegamingbritshow
# game-move
# ace-trainer-liam
# captain-falcore
# dan-allen-gaming
# whizl
# supesonicboom
# mitchgames247
# steparu-50e3e2e8-aef7-4fe6-9b97-11a301550193
# dartron
# gamerzakh
# j8khero
# captain-7af1b45f-c440-4854-8bc0-910fa278d4c3
# huzzygames
# bdcool213
# thedonbro
# iamfallfromgrace
# cayinator
# footymanagertv
# toastmangames
# vikinger
# ashtvn
# dusdavidcraft
# wilddogxd
# the-gadget-show
# kiandymundi
# chaospunishment
# workthespace
# justonegamr
# anish-giri
# cubehamster
# utorak007
# bunnyfufuu-71377749-cb88-4171-a7b9-b26ca1c5942d
# uniqueriggers
# grimygamer
# just-dance-uk
# the-fifa-analyst
# chapter-master-valrak
# the-sonic-show
# walnut
# somewhat-awesome-games
# cosmosftw
# mankalor
# daniel-ibbertson
# resonant
# twintendo
# sam5000i
# globe44hd
# valorant-hub
# strafefox
# woodenpotatoes
# bingh0st
# daily-hearthstone-funny-moments
# beanonaboard
# dutchmash
# tomohawk
# chonnygame
# green-ham-gaming
# shosho-c37f0c46-2e75-4a12-a9cd-db4bd1e2b56b
# eengamestad
# cas-and-chary-vr
# chaiplaysgames
# corpsroyale
# joebuz
# solomon-tetteh
# w4stedspace
# mavric-wolves
# ratedlive
# scottehboeh
# diamantjewel
# ryan-powell
# itsjames
# raikesy
# bullcable-boom-beach
# emz
# raszius-tv
# robfromyoutube-rt8269
# worthy
# oddbawz
# videogamertv
# vash12349
# gafi
# awiibo
# allthesegamez
# zone-c68747d0-582e-4ef0-9a1e-0658ac74e408
# fariko-noway
# cosmic-contrarian
# dropster
# tomfifa17heaven
# samantha-strange
# jentplays
# desk
# speedy-785ba82a-c809-4346-a207-3f2206550e4b
# peterscraps
# kyous
# hembohero
# corkscrew2
# mrgstar321
# the8thhawk
# push-square
# xusesgb
# xkubrak1
# norryrampage
# mercadergaming
# revestoffer
# theskitzmachine
# slippy-slides
# sorastro-s-painting
# rashaunzyash
# elmapuddy
# nidalevi
# zeroempires-age-of-empires-2
# thebigpayback-slot-machine-videos
# nerdfire
# chris-spooner-motoring
# banjotown
# pocket-gamer
# manny-plus
# bateson87plus
# top-hat-gaming-man
# perramcrowe
# slaydra
# paskie-rokus
# gaming-faster-than-light
# z-one-n-only-gaming
# toomanymoths
# whatthehai
# jamiy-jamie
# dexerto
# w92baj-minecraft-and-games
# kiraberry
# frantic
# sunpi
# darkoblox
# prodcharles
# z-cerealglitchers
# cleggy
# heezerulesnl
# ihazcarrot
# dylbobz
# ben-frizzlenpop
# doctorbenjy-fm
# cjugames
# thetoxic-avenger666
# thekknowley
# the-android-miner
# hammeh-overwatch-failcraft
# themusicalknight
# merl
# dani-visser
# pelle-48d79bfc-d1ce-4a6f-bd43-83f215c1c3d4
# ptesh
# azzatru
# claudiu
# trevortrolls
# monarchsfactory
# warface-5c66af1b-113b-4c7d-91f0-f18f060f94de
# twinity
# cromo-plays
# geekism
# tommy-40c71a20-7917-4180-9209-99038fcda719
# tutotoons-games
# justchrisnl
# e-divisie
# unspoken-ouch
# ruler-3665bd80-dda5-4da7-a17b-5da3d50b014e
# itsmyyard
# volound
# eagle-dynamics-digital-combat-simulator
# patch-655635f8-dc25-4bc9-9553-927c48cc1466
# gaming-palooza-empire
# definch
# sorcererdave
# redgamingtech
# nomcomms
# hocgaming
# snakedoctorchannel
# yogscast-caff
# texzl
# planet-coaster
# massi-9ebaa0f8-db73-490f-a9ad-471584217300
# zafrostpet
# emorsomething
# deluxe345
# football-manager
# sasxsh4dowz
# fato
# retrogametech
# chilli-09d01b47-dfd1-497a-b446-df8f6339a342
# fullas-games
# inters3ct
# simpzy
# dicebreaker
# masterkizz
# chawesy
# kiwo
# yoshiller
# magztv
# wonuf
# bitmoredave
# cad5150
# vaulty
# coppersan
# emzy255
# maxime-mxm
# chiefavalon-clash-royale
# officialnerdcubedlive
# obey-raves
# matt-davies
# gbw
# dameandthatgame
# gamezplay
# thetacticalbrit
# cobrak
# make-test-battle
# therealsma
# jphanta
# koil1990
# boosterkings
# brainscratch-commentaries
# ozzaworld
# simul8
# jellyelite
# the-beard-guys
# itsbear
# quicktiming
# veggie-gamer
# rotikhaase-msp
# puck-redflix
# tom97
# kiriothtv-gaming-community-quality
# game-score-fanfare
# lazer-jet
# getgoodguy
# fariko-killaj
# twistie3
# expe
# thetrophymunchers
# curtis-price
# regit
# jarradplays
# cutzy
# yogaflame24
# slotnonaquayt
# havian
# cginfernoblast
# kim-justice
# that-video-games-show
# alex-gillon
# vintage-matthews
# itsjabo
# mrsp3ctre
# jawoodle
# proplanty
# feintattacks
# ninja-theory
# hikomikos-pl
# pingy
# davincstylegames
# valkia
# scoutingforfifa
# hazard-ish
# the-asmr-gamer
# thegamingdefinition
# cheezhofficial
# mcrooster
# ayy-lmao-c1b9649b-1620-42ee-a84d-e1d2edcd0308
# gamermusclevideos
# litanah
# more-james-turner
# creachick-games
# mghplays
# madmaker7
# playstation-for-the-players
# dota-poop
# kriticalkris
# lame-positief
# gamebyte
# racevidzzzftw
# emkay-e8626d4f-44bb-4557-a051-e92def44fb39
# quackalakes
# planet-chucky
# thelondonproject-channel
# ve3tro
# lewis-and-ben-save-the-world
# scott-vance
# grimlygaming
# deserialgamer
# megagwolf
# team-vvv
# fraser2themax
# shipster1912
# nomad-colossus
# plk
# calliemacn
# mattjestic-gaming
# minigod951-old-foxy-fox
# peysplays
# flair-fifa
# tobyleighton
# thedukesofgamers
# vulcanhdgaming
# fil-663e78f9-f768-4c48-a7dc-c48cdb74850e
# spammals
# james_179
# jarno-opmeer-clips
# kirbz
# iswift
# rzed
# xqii
# premydaremy
# elitesnipersrf
# aborder-prince-warhammer-lore
# nugard123
# theemo
# faze-jzpr
# richtheman
# itsjustjord
# travingel
# the-gaming-claw
# skawo
# animated-muscle
# the-game-hub
# generzon
# destinyoverwatch
# wonchop
# chloe-evans
# good-game-029a78a2-fafd-4bbe-bfff-acd976e350f0
# conquest
# phy-games
# switchy
# veloce-jaaames
# skism-gaming
# xaine-s-world
# victor-007
# rare-ltd
# smash-gaming-frazzz
# cool-ghosts
# game-2e174ef7-c4f8-4b0e-80fe-f69f8b551114
# power-unlimited
# rebellion
# jordi-b96f4a69-000d-49cb-b77e-50150c269fda
# loki-doki
# catmanjoe
# alexzafro
# aussiegg
# dannyonpc
# media-molecule
# kickx-games
# hashtag-united-esports
# thegebs24
# kikoskia
# n64-glenn-plant
# two-angry-gamers-tv
# coppa
# tactical-advance
# remyinthesky
# jonty-sl
# golf-clash
# kindafreakyy
# dastactic
# playguin
# silo-entertainment2
# christalraine
# bob-hall
# gaming-with-griff-griffin
# cesaritox09
# longearedfox
# beech
# zambing-g2k
# payton
# androidizen
# malakith-skadi
# the-farmsim-guy
# vizion-9c3514cc-9bd7-4499-afb0-c188fd5e99a8
# bubadu
# kasodus
# silvernews
# futfreak-fifa-mobile-packs
# supermacbrother
# thelegendofrenegade
# gary1q2
# joebilinehd-fifa-mobile-18
# fifizlo
# 1-dead-zombies-youtuber
# vlekkeloos
# landy-kid
# itslars
# tasselfoot
# scarfulhu
# miggy
# thekie25
# r4di
# duderandom84
# skid
# slyzer
# madgaz-gaming
# divide
# a-tribe-called-cars
# carf-darko
# ubisoft-australia
# jay-rpg
# gamesweasel
# leader-9f581ba6-fc50-4525-bc06-70b9a1235550
# 2k-united-kingdom
# steejo
# lady-luna
# gamingtagsnl
# curtizse7en
# call-me-dougan
# epicnng
# 2aa183ad-8424-4798-92d0-366639c7d2ed
# septicfalcon
# thegamerwalkthroughs
# liam-robertson-video-game-history-guy
# mt2oo8
# maxtoothelimit
# vidiots-b755a462-65d6-43cc-81f9-0dbbe19a3385
# potgrond
# kjmodsminecraft
# mrjag
# edit-ed
# mightyteapot
# apps-walkthrough-guides
# cloud-plays
# king-clasher-clash-of-clans
# team-secret-fan-community
# rising-fx
# ilogicshd
# fut-fg
# testedmodz
# squicx
# swordless-link
# dutch-royal-knights
# swagg-cream
# koning-fifa
# evanz111
# littlebig-world
# yorkie
# stealthtiger
# blaruethezebra
# mutantmedicus-minecraft-more
# azaftw
# best-strike
# tonykoknl
# oneamongstmany
# nickslots-twitch-casino-streamer
# scorpionvongaming
# ninja-kuma-let-s-plays-reactions-memes
# octavius-king
# nexus-productions
# danstube-tv
# zemay
# drawyah
# joshflip1989
# crafterdazbg
# yolotigolandgames
# gamen4bros
# thebeardypenguin
# platform32
# h3dsh0t
# officiallydevin
# dyerzy
# gon-kappa
# gardie
# iam-naveed
# chaos-gaming
# prepare-to-try
# jeremy-verburg
# hellfirecomms
# gamertag-vr
# aeris
# zova
# ubaproductionz
# focuss-kanaal-omtrent-fifa
# snorth93
# sirbacon321
# mrandersonlp
# steven-c-bear
# brue-computing
# css172
# azikura
# blackdragon
# greenalink
# crystalfissure
# genie-f2c5e292-4826-4bea-b329-14700a281698
# vortexxygaming
# simonb1471
# derpishgamer
# weazzy
# virtual-farmer
# dodgykebaab
# m-yh-m
# barakyeet
# cinno
# calplex
# readysitgeek
# rixy
# dardan
# gamesalike
# how-big-is-the-map
# tidgney
# drdrillvga
# trickyacidgaming
# luuwatgaming
# purespam
# xtge
# cali
# winky-822a6e46-2131-4e18-a6bb-348593de1bb8
# avithdgamer-virtual-pro-look-a-likes
# honest-gaming
# harrison-james
# mattj155
# mr-mirror
# joefl96
# chayification
# vinny-vr
# v-for-voice
# misterbo
# low-mana-gaming
# shaedy-squad
# heisenberg-gaming
# nintendo3dschannel
# billyeatworld
# zerofoxfk
# neversurrendr
# generalsecura
# fjmgaming
# nltrucker
# f4cepa1m-x_0
# totalcretin
# walshie
# thedmginfo
# fearlessflourish
# buildz
# bananaraccoon
# tape-gaming
# laundrykid2005
# bossa-studios
# tho-bov
# luuk-fc
# dino-hajderovic
# thegrumpyspanner
# lekker-spreken
# a2z-interactive
# rubendelight-animates
# mikenactor
# wiredproductionsltd
# mrvuule
# soetie
# spammiej
# onlinegam3r
# empirezz
# adam-pearson
# armored-warfare-034af1fb-68fe-4516-8363-c233b101a39f
# gorgeous-gaming
# total-war-zone
# the-games-shed
# ability-drain
# guga-gejmerka
# vonoxnl
# ragnarobb
# smithdoggy
# eb-games-australia
# apocalypse
# ljb0
# game-hunter
# fsxnoob-games-more
# intimidategaming
# purplefire
# bombsturfreceipts
# smileb4death
# pointyhairedjedi
# tobical-studios
# ipugsiehd
# chocolatewe
# jamiethekid00
# leez0ne
# totalmk
# jimbob-soss
# allgunsraveing
# urgntjustice
# sanquo
# freddo-films
# faceitvods
# justjason
# dr-gud-times
# goulds
# khool
# tynamite
# weplay-esports-dota2
# tigo_
# daminous-purity
# pairofexiles
# thefullsetup
# killerkev
# muckluck
# vppaf
# jan-willem-erik
# teo-w-gamelandii
# webe
# ferk
# subline
# southpawracer
# team-fnl
# goukigod
# steve-benway
# squibby-the-squid
# dream-assembly
# myunboxingsandfun
# good-game-spawn-point
# velcomia
# dan-toppy
# actionhans
# tmak
# bigplaysinc
# tezla
# gram-games
# mrthunderwing
# tolop
# seti-scopes
# cfx-squad
# fifawondahd
# paradise-decay
# supagogoman
# bladerunnerblues
# twitchnitr0
# iq-gamer
# bbqturkman-age-of-empires-2
# colloseusx
# steadfst
# weetjewatlaatmaar
# laurenxmsp
# sizzgames
# egx
# phantomj-hd
# qelric
# hetvideospel
# het-aapje
# prio1gaming
# ray-aviation
# foxydude98
# gaming-with-jollins
# movienations-studio
# ijjosh
# kmillshd
# rib-sosay
# dutchpointhd
# slitherinegames
# templarscrusade01
# datsabucket
# greentorn
# edgymachine
# codydaviestv
# aussiegamerchick
# qualityxa-daily-destiny-videos
# stoked
# idc_sao
# odyssey-gaming
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-876499455ef0> in <module>
#     154
#     155     for category in Topic:
# --> 156         extract_category_dom_colours(category.value, clusters)
#     157         # only do gaming for now
#     158         break
#
# <ipython-input-7-876499455ef0> in extract_category_dom_colours(category, clusters)
#      93     all_category_thumbnails = []
#      94     for creator in tqdm(list(videos_info.keys())):
# ---> 95         print(creator)
#      96         all_creator_thumbnails = []
#      97
#
# c:\Users\irene\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# c:\Users\irene\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# c:\Users\irene\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\Users\irene\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
CATEGORY_PATH = "../data/thumbnail-dom-colours/categories"
CREATORS_PATH = "../data/thumbnail-dom-colours/creators"

import matplotlib.pyplot as plt
import json
import os

with open(os.path.join(CATEGORY_PATH, "gaming.json"), "r") as f:
        print("Loading creator's videos")
        d_and_c = json.load(f)

colours = d_and_c["colours"]
p = d_and_c["perc"]

print(colours)
print(sum(p))

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
# labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = p
# explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
_, _ ,m = ax1.pie(sizes, autopct='%1.1f%%', colors=colours, shadow=True, startangle=90)
[m[i].set_color('white') for i in range(len(m))]

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# Loading creator's videos
# ['#020201', '#000b23', '#1b0100', '#011502', '#43000e', '#01050d', '#0e0100', '#010b38', '#2b0101', '#130214']
# 0.9990000000000001
